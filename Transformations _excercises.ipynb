# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinDearco/FEWNet/blob/main/Transformations%20_excercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Import data**

# %%
! wget -nc https://lazyprogrammer.me/course_files/airline_passengers.csv
# Out:
# --2025-02-26 17:14:49--  https://lazyprogrammer.me/course_files/airline_passengers.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 172.67.213.166, 104.21.23.210, 2606:4700:3030::ac43:d5a6, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|172.67.213.166|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2036 (2.0K) [text/csv]
# Saving to: ‘airline_passengers.csv’
#
# airline_passengers. 100%[===================>]   1.99K  --.-KB/s    in 0s
#
# 2025-02-26 17:14:49 (33.5 MB/s) - ‘airline_passengers.csv’ saved [2036/2036]

# %% [markdown]
# ## **Import packages**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import boxcox

# %%
df = pd.read_csv('airline_passengers.csv', index_col='Month', parse_dates=True)
df.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# ## **Plot how the data behaves**

# %%
df['Passengers'].plot(figsize=(20,8));

# %% [markdown]
# ## **Power transforming using Square root**

# %%
df['SqrtPassengers'] = np.sqrt(df['Passengers'])
df['SqrtPassengers'].plot(figsize=(20,8));

# %% [markdown]
# OK, so we can see that the Time series has been squashed down slightly, but the amplitude of the seasonal pattern still seems to increase over time.

# %% [markdown]
# ### **Log transform**

# %%
df['LogPassengers'] = np.log(df['Passengers'])
df['LogPassengers'].plot(figsize=(20,8));

# %% [markdown]
# OK, so this log transform seems to do a pretty good job at squashing down the data to make it look more uniform and time.

# %% [markdown]
# ## **Box Cox transform**

# %% [markdown]
# The final step will be to do a box cox transform, so this function takes in a one dimensional data set as input and it returns the transform data along with the optimal value of lambda. So you can see we've assigned the result to the variables called data in Lam.

# %%
data, lam = boxcox(df['Passengers'])

# %%
lam
# Out:
# 0.14802254856840585

# %% [markdown]
# The next step is to just print out lamb to see what value we got.
#
# So we get about zero point one five, which is kind of in between the log transform in the square root transform, the next step is to assign our box --'s transform data to a new column in our data frame and make a new plot.

# %%
df['BoxCoxPassengers'] = data
df['BoxCoxPassengers'].plot(figsize=(20,8));

# %% [markdown]
#  we see that it definitely looks like something in between the square root and the log transforms.
#
# ---
